# %% [markdown]
# $1.a$
#
# $\frac{ x^{k-1}  e^{-x/ \theta } }{\    \theta ^{k}  \Gamma (k) } I(0, \infty )X$
#
#
#
# $  \frac{\ 1}{\Gamma (k)  \theta ^{k} }  \int_0^ \infty    \ x^{k-1} e^{-x/ \theta}$
#
#
#
# $\frac{\ 1}{\Gamma (k)  \theta ^{k} }  \int_0^ \infty    \  \theta u^{k-1} e^{-u   } \theta du$
#
#
#
# $\frac{\ 1}{\Gamma (k)   }  \int_0^ \infty    \   u^{k-1} e^{-u   }  du=1$
#
#
#
# $Dado que$
#
#
#
# $\ r=k  \int_0^ \infty    \   u^{k-1} e^{-u   }  du$
#
# $ u_{r}=  \frac{\ 1}{\Gamma (k)  \theta ^{k} }  \int_0^ \infty    \ x^{k+r-1} e^{-x/ \theta}du$
#
#
#
# $ \frac{\ \theta^{k+1} }{\Gamma (k)  \theta ^{k}} \int_0^ \infty    \ u^{k+r-1} e^{-u/}du$
#
#
#
# $\frac{\ \theta^{r} \Gamma (k+r) }{\Gamma (k) }$
#
# $E[X]=k\theta$
#
#
# $VAR[X]=\theta^{2}$

# %% [markdown]
# $1.b$
#
#
# $ fX(x)= \frac{\ 1}{\ \theta } e^{-1/ \theta } I (X)$
#
#
#
# $ P(X \leq x)=F(X; \theta )=1- e^{-x/ \theta }$
#
#
#
# $ X_{q}= \theta ln[1/(1-q)] $
#
#
#
# $ E[X]= \theta $
#
#
#
# $VAR[X]=   \theta ^{2} $

# %% [markdown]
# $2.a$
#
#
# $
# \begin{bmatrix}n & P & n.P\\
# 2 & 1/36 & 2/36\\
# 3 & 2/36 & 6/36\\
# 4 & 3/36 & 12/36\\
# 5 & 4/36 & 20/36\\
# 6 & 5/36 & 30/36\\
# 7 & 6/36 & 42/36\\
# 8 & 5/36 & 40/36\\
# 9 & 4/36 & 36/36\\
# 10 & 3/36 & 30/36\\
# 11& 2/36 & 22/36\\
# 12 & 1/36 & 12/36\\
# \end{bmatrix}
# $
#
# $E[X]=\sum (n.P)$
#
# $E[X]=7$

# %% [markdown]
# $2.b$
# Dada la Función:
#
# $
# x =\begin{cases}xy/96 & 0<x<4 , 1<y<5\\o & otro modo & \end{cases}
# $
#
#
# $E[X]= \int_0^4 x  \frac{\ xy}{\ 96} dx$
#
#
#
# $E[X]=   \frac{\  x^{3} y}{\ 288} =  \frac{\ -2y}{\ 9}$
#
#
#
# $E[Y]= \int_1^5 y  \frac{\ xy}{\ 96} dy$
#
#
# $E[Y]=   \frac{\  y^{3} x}{\ 288}  =  \frac{\ 31X}{\ 72} $
#
#
#
# $E[xy]= \int_0^4  \int_1^5 x y  \frac{\ xy}{\ 96} dydx$
#
#
#
# $E[xy]=  \frac{\ x^{2} y^{3} } {\ 576} =  \frac{\ - y^{3} }{\ 36}$
#
#
#
# $E[2x+3y]=E[2x]+E[3y]=2E[X]+3E[Y]$
#
#
#
# $2E[X]+3E[Y]= \frac{\ -4y}{\ 9}+\frac{\ 62x}{\ 72}$
